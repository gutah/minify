# %%
from folder import newfolder     
from tinify import minify
        

def main():
    print("Starting...")


    # Root path
    mypath = r'C:\Users\gusta\Downloads\utopiar_data\Fotos'
    
    newfolder = create_folder(mypath)
    print("Getting photos...")
    files = searchFiles(mypath)
    ("Minifing photos;")
    minify(files, newfolder)
    
    
if __name__ == "__main__":
    main()
# Out:
# Starting...
# Folder already exist.
# Getting photos...
# Working on... FEMINISA-2.jpg
# Working on... feminisa.jpg
# Working on... moletom-capuz.jpg
# Working on... moletom-sem-capuz.jpg
# Working on... banners-ecobag.jpg
# Working on... cachecois.jpg
# Working on... calça.jpg
# Working on... camisas.jpg
# Working on... chemise.jpg
# Working on... echarpe.jpg
# Working on... kaftans.jpg
# Working on... kimonos.jpg
# Working on... lenço-quadrado.jpg
# Working on... lenços.jpg
# Working on... moletom.jpg
# Working on... outlet.jpg
# Working on... shorts.jpg
# Working on... vestidos-longos.jpg
# Working on... vestidos.jpg
# Working on... feminisa.jpg
# Working on... Natália-rios-mais-pinga-2.jpg
# Working on... Todos.jpg
# Working on... gif-3.gif
# An error occured:gif-3.gif
# Working on... camisão.jpg
# Working on... home-coleção-nat-rios2.jpg
# Working on... home-coleção-nat-rios3.jpg
# Working on... feminisa.jpg
# Working on... institucional2.jpg
# Working on... moletom.jpg
# ...
